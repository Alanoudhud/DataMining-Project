# %% [markdown]
# # Phase 1 - Data Selection
#
# ## Project Goal
# The goal of this project is to use the Lung Cancer Risk dataset to predict whether a person has lung cancer (Yes/No) using data mining techniques.
#
# ## Dataset Source
# Dataset taken from Kaggle: [Lung Cancer Risk Dataset](https://www.kaggle.com/datasets/mikeytracegod/lung-cancer-risk-dataset)
#
# ## Dataset Description
# - The number of rows and columns will be identified after loading the dataset.
# - Target attribute (Class Label): *LUNG_CANCER*

# %%
import pandas as pd

# Load dataset (make sure the file name matches your upload in Colab or GitHub)
df = pd.read_csv("Raw_dataset.csv")

# Shape of dataset
print("Shape:", df.shape)

# Data types of columns
print("\nData Types:\n", df.dtypes)

# Class distribution
print("\nClass Distribution:\n", df['lung_cancer'].value_counts())

# Show first 5 rows
df.head()
# Out:
# Shape: (50000, 11)
#
# Data Types:
#  patient_id                     int64
# age                            int64
# gender                        object
# pack_years                   float64
# radon_exposure                object
# asbestos_exposure             object
# secondhand_smoke_exposure     object
# copd_diagnosis                object
# alcohol_consumption           object
# family_history                object
# lung_cancer                   object
# dtype: object
#
# Class Distribution:
#  lung_cancer
# Yes    34364
# No     15636
# Name: count, dtype: int64
#    patient_id  age  gender  pack_years radon_exposure asbestos_exposure  \
# 0      100000   69    Male   66.025244           High                No
# 1      100001   32  Female   12.780800           High                No
# 2      100002   89  Female    0.408278         Medium               Yes
# 3      100003   78  Female   44.065232            Low                No
# ...
